# %%
import numpy as np

# %%
a = np.poly1d([1,1])
b = np.poly1d([1,-1])

# %%
a, b
# Out:
# (poly1d([1, 1]), poly1d([ 1, -1]))

# %%
a*b
# Out:
# poly1d([ 1,  0, -1])

# %%
#!pip install sympy

# %%
from sklearn.datasets import load_iris

iris = load_iris

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\shchoi\Documents\ds_study\14. cost function.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shchoi/Documents/ds_study/14.%20cost%20function.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> iris.info()
#
# AttributeError: 'function' object has no attribute 'info'
