# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (4.14.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\shchoi\anaconda3\envs\ds_study\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()
driver.get("https://www.naver.com")

# %%
driver.quit()

# %% [markdown]
# ## 2. 셀프 주요소가 정말 저렴할까? - 데이터 확보하기 위한 작업
#  - https://www.opinet.co.kr/searRgSelect.do
#  - 사이트 구조 확인
#  - 목표 데이터
#
#     - 브랜드
#     - 가격
#     - 셀프 주유 여부
#     - 위치

# %% [markdown]
# ## 3. 셀레니움으로 접근

# %%
from selenium import webdriver

# %%
url = "https://www.opinet.co.kr/searRgSelect.do"
driver = webdriver.Chrome()
driver.get(url)

# %% [markdown]
#  - 문제
#     - 해당 주소로 한 번에 접근 안됨(지금은 되는듯?)
#     - 메인페이지로 접속되고, 팝업창 뜸
