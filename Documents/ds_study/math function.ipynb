# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-3,2,100)
y = 3*x**2+2

# %%
import matplotlib as mpl


plt.figure(figsize=(12,8))
plt.plot(x,y)
plt.grid()
plt.xlabel('$x$')
plt.ylabel('$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
x = np.array([10,100,1000,10000,100000,1000000,10000000])

(1 + 1/x)**x
# Out:
# array([2.59374246, 2.70481383, 2.71692393, 2.71814593, 2.71826824,
#        2.71828047, 2.71828169])

# %%
u = np.linspace(0,1,30)
v = np.linspace(0,1,30)

# %%
U,V = np.meshgrid(u,v)

# %%
Z = (1+u**2) + v / (1+v**2)
Z
# Out:
# array([1.        , 1.03563087, 1.0733953 , 1.11305449, 1.15438086,
#        1.19716301, 1.24120983, 1.28635386, 1.33245347, 1.37939417,
#        1.42708885, 1.47547717, 1.52452422, 1.57421858, 1.62456987,
#        1.67560619, 1.72737127, 1.77992171, 1.83332432, 1.88765355,
#        1.94298929, 1.99941474, 2.05701478, 2.11587439, 2.17607748,
#        2.23770588, 2.30083861, 2.36555132, 2.43191585, 2.5       ])

# %%
fig = plt.figure(figsize=(7,7))
ax = plt.axes(projection='3d')

ax.xaxis.set_tick_params(lavelsize=15)
ax.yaxis.set_tick_params(lavelsize=15)
ax.Zaxis.set_tick_params(lavelsize=15)

ax.set_xlabel('$x$', fontsize=20)
ax.set_ylabel('$y$', fontsize=20)
ax.set_zlabel('$z$', fontsize=20)

ax.scatter3D(U,y,Z)
